# %%
from pathlib import Path

abs_path = Path(__file__).resolve().parent

print(abs_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 from pathlib import Path
#       2
# ----> 3 abs_path = Path(__file__).resolve().parent
#       4
#       5 print(abs_path)
#
# NameError: name '__file__' is not defined

# %%
from src.Collect_and_Process import collection

collection.Data_Collection().Collection()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from src.Collect_and_Process import collection
#       2
#       3 collection.Data_Collection().Collection()
#
# ModuleNotFoundError: No module named 'src'

# %%
from src.Collect_and_Process import Process

Process.Pre().Read_info()
Process.Pre().Normalization()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.Collect_and_Process import Process
#       2
#       3 Process.Pre().Read_info()
#       4 Process.Pre().Normalization()
#
# ModuleNotFoundError: No module named 'src'

# %%
from src.db import analyzer

Ana_sql = analyzer.FraudAnalyzer()

print(f"{'+'*50}")
print(Ana_sql.get_fraud_rate())
print(f"{'+'*50}\n")

print(f"{'+'*50}")
print(Ana_sql.get_anomalies())
print(f"{'+'*50}\n")

print(f"{'+'*50}")
print(Ana_sql.get_fraud_patterns())
print(f"{'+'*50}\n")
